# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
# Inisialisasi StopWordRemover dan Stemmer
stopword_factory = StopWordRemoverFactory()
stopword_remover = stopword_factory.create_stop_word_remover()

stemmer_factory = StemmerFactory()
stemmer = stemmer_factory.create_stemmer()

# stopward
def preprocess_text(text):
    # Menghapus stopword
    text_no_stopwords = stopword_remover.remove(text)
    # Melakukan stemming
    text_stemmed = stemmer.stem(text_no_stopwords)
    return text_stemmed

# non-stopward
# def preprocess_text(text):
#     # Langsung melakukan stemming tanpa menghapus stopword
#     return stemmer.stem(text)

# %%
# Muat data dari file Excel
data = pd.read_excel('REVIEW KEBIJAKAN MBG.xlsx')

# Pra-pemrosesan teks
data['text'] = data['text'].apply(preprocess_text)

# 🔁 Mapping label sentimen ke angka
label_mapping = {'Netral': 0, 'Positif': 1, 'Negatif': 2}
data['sentiment'] = data['sentiment'].map(label_mapping)

# Misalnya data memiliki kolom 'text' untuk teks dan 'sentiment' untuk label sentimen
texts = data['text']
sentiments = data['sentiment']

# Split data menjadi data pelatihan dan data uji
X_train, X_test, y_train, y_test = train_test_split(texts, sentiments, test_size=0.3, random_state=42)

# %%
# Inisialisasi CountVectorizer
vectorizer = CountVectorizer()

# Fit dan transform data pelatihan
X_train_counts = vectorizer.fit_transform(X_train)

# Transform data uji
X_test_counts = vectorizer.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# Inisialisasi 
model = LogisticRegression(max_iter=1000)

# Latih model
model.fit(X_train_counts, y_train)

# Prediksi sentimen untuk data uji
predictions = model.predict(X_test_counts)

# %%
# Menampilkan hasil evaluasi
print("Evaluasi Model (Logistic Regression) dengan Stopword:")
print(classification_report(y_test, predictions))

# Menampilkan beberapa hasil prediksi
print("\nBeberapa hasil prediksi:")
for text, sentiment in zip(X_test, predictions):
    print(f'Teks: {text}\nPrediksi Sentimen: {sentiment}\n')

# Ekspor hasil prediksi ke file Excel
results = pd.DataFrame({'text': X_test, 'predicted_sentiment': predictions})
results.to_excel('predictions(LR)non-sw.xlsx', index=False)

print("Hasil prediksi (Logistic Regression) telah diekspor ke 'predictions (LR).xlsx'.")

results = pd.DataFrame({'text': X_test, 'true_sentiment': y_test, 'predicted_sentiment': predictions})
results.to_excel('predictions-true(LR)non-sw.xlsx', index=False)

print("Hasil prediksi (Logistic Regression) telah diekspor ke 'predictions-true(LR).xlsx'.")
# Out:
# Evaluasi Model (Logistic Regression) dengan Stopword:
#               precision    recall  f1-score   support
#
#            0       1.00      0.44      0.62         9
#            1       0.77      0.95      0.85        21
#            2       0.87      0.87      0.87        30
#
#     accuracy                           0.83        60
#    macro avg       0.88      0.75      0.78        60
# weighted avg       0.85      0.83      0.82        60
#
#
# Beberapa hasil prediksi:
# Teks: gizi gimana nanti apa cuma asal kenyang
# Prediksi Sentimen: 2
#
# Teks: lah bukan lebih penting baik kualitas guru sama fasilitas sekolah makan siang oke kalo guru kurang kompeten sama aja boong dong prioritas kok gin sih
# Prediksi Sentimen: 2
#
# Teks: jangan program cuma jadi ajang korupsi jamaah
# Prediksi Sentimen: 2
#
# Teks: kalo makan enak bakal banyak yg makan
# Prediksi Sentimen: 2
#
# Teks: transparansi anggar kunci
# Prediksi Sentimen: 2
#
# Teks: ini langkah nyata putus mata rantai miskin
# Prediksi Sentimen: 1
#
# Teks: investasi baik buat generasi datang
# Prediksi Sentimen: 1
#
# Teks: yang paling gue khawatirin soal standar gizi bersih gimana cara nih pasti tiap sekolah tiap hari makan sesuai standar gak bikin anak sakit kalo cuma asalasalan doang mending gak usah deh lebih bahaya kalo makan gak higienis ini perlu awas ekstra ketat sih pihak wenang
# Prediksi Sentimen: 2
#
# Teks: gak mungkin sih bisa rata daerah pencil sulit
# Prediksi Sentimen: 1
#
# Teks: anakanak hak dapat asupan gizi yg baik
# Prediksi Sentimen: 1
#
# Teks: optimis program akan hasil
# Prediksi Sentimen: 1
#
# Teks: jangan jadi beban sekolah yg fasilitas minim
# Prediksi Sentimen: 2
#
# Teks: ini program kayak lebih citra doang drpd niat tulus buat anakanak kalo beneran peduli udah dulu wujud kenapa baru sekarang pas udah mau milu ato transisi gitu rakyat jg gak bodohbodoh buat nilai jangan cuma janji manis doang
# Prediksi Sentimen: 1
#
# Teks: moga tani lokal jg manfaat program
# Prediksi Sentimen: 1
#
# Teks: moga lancar gak halang
# Prediksi Sentimen: 1
#
# Teks: evaluasi independen program makan siang gratis sangat perlu
# Prediksi Sentimen: 0
#
# Teks: potensi tantang bijak makan siang gratis perlu imbang
# Prediksi Sentimen: 0
#
# Teks: korupsi korupsi udah biasa
# Prediksi Sentimen: 2
#
# Teks: duit aja buat gin gilir yg susah
# Prediksi Sentimen: 2
#
# Teks: wajib sukses program demi anakanak
# Prediksi Sentimen: 1
#
# Teks: makan siang gratis gin doang para oknum gk dpt motong anggar makan siang
# Prediksi Sentimen: 2
#
# Teks: moga sedia bahan pangan lokal ikut tingkat
# Prediksi Sentimen: 1
#
# Teks: ini ide brilian pasang pilih pasti anakanak jadi makin semangat ajar
# Prediksi Sentimen: 1
#
# Teks: moga program tidak beban guru tugas tambah
# Prediksi Sentimen: 1
#
# Teks: terima kasih pak prabowo program mantap
# Prediksi Sentimen: 1
#
# Teks: jangan ada bocor dana yg rugi negara
# Prediksi Sentimen: 2
#
# Teks: moga semua pihak dukung masa depan anak
# Prediksi Sentimen: 1
#
# Teks: alhamdulillah anakanak jadi lebih semangat sekolah sejak program jalan
# Prediksi Sentimen: 1
#
# Teks: kalo beneran laksana baik bisa jadi game changer buat masa depan anak bangsa apalagi buat dari keluarga kurang mampu bantu banget salut
# Prediksi Sentimen: 1
#
# Teks: perintah perlu timbang semua masuk bagai pihak kait program
# Prediksi Sentimen: 0
#
# Teks: ide bagus perlu kaji yg lebih dalam
# Prediksi Sentimen: 2
#
# Teks: duh mikir anggar makan siang gratis gede udah bikin puyeng kalo gak kelola bener yg jd lubang korupsi doang belum soal kualitas distribusi yg gak rata gimana mau nutupin butuh nutrisi juta anak kalo harga bahan pokok tiap daerah bedabeda kayak bakal banyak drama sih nanti
# Prediksi Sentimen: 2
#
# Teks: program makan siang gratis wacana yg perlu kaji lebih kita tunggu aja bagaimana skema detail
# Prediksi Sentimen: 2
#
# Teks: pikir dampak jangka panjang jangan cuma euforia saat
# Prediksi Sentimen: 2
#
# Teks: biaya awat anak sakit makan higienis bakal lebih mahal mikir panjang dikit lah
# Prediksi Sentimen: 2
#
# Teks: perlu mekanisme adu awas masyarakat program
# Prediksi Sentimen: 2
#
# Teks: salut buat inisiatif pasti banyak anak yg bantu
# Prediksi Sentimen: 1
#
# Teks: makan siang gratis buku ajar bayar lucu
# Prediksi Sentimen: 2
#
# Teks: makan siang gratis bisa jadi langkah positif gantung bagaimana laksana lapang
# Prediksi Sentimen: 1
#
# Teks: ribet sih gak tau deh jd apa
# Prediksi Sentimen: 2
#
# Teks: ini sempat tingkat kualitas sdm
# Prediksi Sentimen: 1
#
# Teks: anggar gin gede mending buat gaji guru honorer
# Prediksi Sentimen: 2
#
# Teks: alhamdulillah banget kalo beneran jalan anakanak jd lebih semangat sekolah gak pusing bekal
# Prediksi Sentimen: 1
#
# Teks: anakanak sekolah sangat butuh asupan gizi yg cukup ini solusi
# Prediksi Sentimen: 0
#
# Teks: kalo makan enak anakanak bakal buangbuang makan
# Prediksi Sentimen: 2
#
# Teks: ini udah jd lahan basah buat oknumoknum gak tanggung jawab wong dana bansos aja banyak yg sunat ini yg anggar gede banget gak heran sih kalo ada kasus seleweng waspada aja deh jangan sampe anakanak jd korban
# Prediksi Sentimen: 2
#
# Teks: makan siang gratis oke sih ide kalo ngurusnya gak bener yg malah jd ladang korupsi udah sering jadi yg gitugitu kita gak yakin deh mulus
# Prediksi Sentimen: 2
#
# Teks: kalo makan fresh gimana
# Prediksi Sentimen: 2
#
# Teks: jangan sampe malah bikin anakanak jadi manja
# Prediksi Sentimen: 1
#
# Teks: dari pusing mikirin makan siang mending fokus kurikulum yg bagus
# Prediksi Sentimen: 2
#
# Teks: sungguh makin maju aja bangsa
# Prediksi Sentimen: 2
#
# Teks: moga tani lokal dapat manfaat program
# Prediksi Sentimen: 1
#
# Teks: udah pusing mikirin biaya hidup eh yg gratis lumayan banget
# Prediksi Sentimen: 1
#
# Teks: ini bukti perintah peduli sama masa depan anak bangsa
# Prediksi Sentimen: 1
#
# Teks: gimana sih awas apa cukup sdm yg punya integritas buat ngecek tiap sekolah tiap hari kalo cuma ngandelin lapor doang bakal gampang manipulasi perlu sistem audit yg kuat partisipasi masyarakat yg aktif buat ngawasin biar program gak bocor
# Prediksi Sentimen: 2
#
# Teks: ini gerak roda ekonomi lokal utama umkm
# Prediksi Sentimen: 1
#
# Teks: yang paling khawatir data anak yg tepat sasar jangan sampe yg kaya ikut dapet yg miskin malah
# Prediksi Sentimen: 2
#
# Teks: moga program bisa jalan sesuai rencana tidak kendala arti
# Prediksi Sentimen: 1
#
# Teks: jangan ada diskriminasi bagi makan
# Prediksi Sentimen: 2
#
# Teks: transparansi kelola anggar makan siang gratis sangat krusial
# Prediksi Sentimen: 2
#
# Hasil prediksi (Logistic Regression) telah diekspor ke 'predictions (LR).xlsx'.
# Hasil prediksi (Logistic Regression) telah diekspor ke 'predictions-true(LR).xlsx'.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = model.predict(X_test_counts) 
cm = confusion_matrix(y_test, y_pred, labels=[0, 1, 2])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['netral', 'positif', 'negatif'])
disp.plot()

# %%
# Fungsi untuk menganalisis teks baru
def analyze_text(text):
    preprocessed = preprocess_text(text)
    text_counts = vectorizer.transform([preprocessed])
    return model.predict(text_counts)[0]

# Menganalisis teks dari input pengguna
while True:
    user_input = input("\nMasukkan teks untuk analisis sentimen (atau ketik 'x' untuk keluar): ")
    if user_input.lower() == 'x':
        break
    sentiment = analyze_text(user_input)
    print(f'Prediksi Sentimen (LR) untuk "{user_input}": {sentiment}')
# Out:
# Prediksi Sentimen (LR) untuk "Program MBG dikhawatirkan akan membebani anggaran negara secara signifikan dalam jangka panjang": 2
# Prediksi Sentimen (LR) untuk "Kualitas gizi makanan yang disajikan dalam program MBG seringkali diragukan dan tidak memenuhi standar": 2
# Prediksi Sentimen (LR) untuk "Implementasi program MBG terlihat kurang matang, dengan banyak masalah distribusi di lapangan": 2
# Prediksi Sentimen (LR) untuk "Banyak pihak menilai program MBG hanya buang-buang uang, lebih baik fokus pada peningkatan kualitas pendidikan": 1
# Prediksi Sentimen (LR) untuk "Anak-anak menjadi tidak terbiasa membawa bekal sehat dari rumah karena adanya program MBG": 1
# Prediksi Sentimen (LR) untuk "Target penerima manfaat program MBG sering tidak tepat sasaran, banyak yang sebenarnya tidak membutuhkan": 1
# Prediksi Sentimen (LR) untuk "Sampah plastik dari kemasan makanan MBG menjadi masalah lingkungan baru di sekolah-sekolah": 1
# Prediksi Sentimen (LR) untuk "Beberapa siswa mengeluhkan rasa makanan MBG yang hambar dan kurang bervarias": 2
# Prediksi Sentimen (LR) untuk "Program MBG dianggap lebih sebagai janji politik populis ketimbang solusi nyata untuk masalah gizi": 2
